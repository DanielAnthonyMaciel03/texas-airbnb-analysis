# %% [markdown]
# ## Austin Listings EDA

# %% [markdown]
# ## Loading the Data Set
# - The first step is to load the data set I will be exploring
# - This will allow me to analyze and inspect:
#     - The shape of my data
#     - Null values
#     - Columns that may or may not be relevant to my business question
#
# - I also like to output a small portion of the data set to get a quick understanding of how the data looks

# %%
import pandas as pd

df = pd.read_csv('../data/listings_Austin.csv')
df.head()
# Out:
#       id                                               name  host_id  \
# 0   5456          Walk to 6th, Rainey St and Convention Ctr     8028
# 1   6448  Secluded Studio @ Zilker - King Bed, Bright & ...    14156
# 2   8502                            Woodland Studio Lodging    25298
# 3  13035      Historic house in highly walkable East Austin    50793
# 4  22828                 Garage Apartment central SE Austin    56488
#
#       host_name  neighbourhood_group  neighbourhood  latitude  longitude  \
# 0        Sylvia                  NaN          78702  30.26057  -97.73441
# 1           Amy                  NaN          78704  30.26034  -97.76487
# 2         Karen                  NaN          78741  30.23466  -97.73682
# 3  Margaret Ann                  NaN          78702  30.26098  -97.73072
# 4         David                  NaN          78741  30.23614  -97.73225
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10533 entries, 0 to 10532
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              10533 non-null  int64
#  1   name                            10533 non-null  str
#  2   host_id                         10533 non-null  int64
#  3   host_name                       10524 non-null  str
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   10533 non-null  int64
#  6   latitude                        10533 non-null  float64
#  7   longitude                       10533 non-null  float64
#  8   room_type                       10533 non-null  str
#  9   price                           10517 non-null  float64
#  10  minimum_nights                  10533 non-null  int64
#  11  number_of_reviews               10533 non-null  int64
# ...

# %% [markdown]
# ## Findings from df.info():
# - Next I like to run df.info() to give me a quick, concise summary of very important features of my data set such as shape, data types, and any null values my data may have
#
# **Shape**
# - We can see that the shape of this data set is (10533, 18)
# - This means there are 10,533 rows/entries and 18 columns/attributes
#
# **Data-types**
# - The data set contains 3 distinct data-types
# - float64 (decmial values)
# - int64 (whole numbers)
# - str (text)
#
# **Null values**
# - df.info() shows us the number of rows that dont have NULL values, for each columm
# - The following columns have entries whos values are NULL and will be handled later on:
#     - host_name             ... 9 NULL values
#     - neighbourhood_group   ... 10533 NULL values
#     - price                 ... 16 NULL values
#     - last_review           ... 1624 NULL values
#     - reviews_per_month     ... 1624 NULL values
#     - license               ... 10533 NULL values
#
#
# **Other potential issues to investigate**
# - 'neighbourhood' column is an integer data type
#     - Since we will never perform calculations on a zip code, this column should be a string data type
#     - Additionally, during data analysis and visualization, a numerical value that is actually categorical may cause issues with grouping and plotting visuals

# %%
df[['price', 'minimum_nights', 'availability_365', 'number_of_reviews']].describe()
# Out:
#               price  minimum_nights  availability_365  number_of_reviews
# count  10517.000000    10533.000000      10533.000000       10533.000000
# mean     414.537701        7.768157        234.909238          55.858920
# std     2896.807897       20.586238        114.102467         104.276866
# min        8.000000        1.000000          0.000000           0.000000
# 25%       86.000000        1.000000        143.000000           2.000000
# 50%      135.000000        2.000000        263.000000          17.000000
# 75%      226.000000        3.000000        339.000000          62.000000
# max    50000.000000      365.000000        365.000000        1305.000000

# %% [markdown]
# ## Findings from df.describe()
# - I also like to run df.describe() on key numerical columns relevant to my business question
# - Running this helps me identify any skewed distributions or outliers that could affect my analysis
#
# **Price:**
# - Min: $8 ... suspiciously low, needs investigation
# - Max: $50,000 ... likely an outlier that could skew analysis
# - Mean: $414 ... likely inflated by extreme values
#
# **Minimum Nights:**
# - Max: 365 nights ... a full year minimum stay suggests some listings
#   are not true short term rentals and may need to be filtered out

# %% [markdown]
# ## Dallas Listings EDA

# %%
df = pd.read_csv('../data/listings_Dallas.csv')
df.head()
# Out:
#         id                                           name    host_id  \
# 0    61878                  MODERN LIVING AND FURNISHINGS   300211.0
# 1   795703       Amazing location walk to Downtown Dallas  4191322.0
# 2  1277933  The Santa Fe Suite and Maxfield Parrish Suite  6904484.0
# 3  1479800        SMU/Trendy Greenville/with Private Bath  3809024.0
# 4  1507428      4323 McKinney Ave studio 8, WIFI, Parking  6063232.0
#
#    host_profile_id    host_name  neighbourhood_group neighbourhood  latitude  \
# 0     1.462515e+18         Rita                  NaN    District 2  32.81690
# 1     1.462534e+18     Michelle                  NaN   District 14  32.80327
# 2     1.462548e+18  C. F. Sandy                  NaN   District 11  32.92449
# 3     1.462532e+18        Holly                  NaN   District 14  32.83103
# 4     1.462697e+18         Joan                  NaN   District 14  32.81961
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
df.info()
df[['price', 'minimum_nights', 'availability_365', 'number_of_reviews']].describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6217 entries, 0 to 6216
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              6217 non-null   int64
#  1   name                            6217 non-null   str
#  2   host_id                         6211 non-null   float64
#  3   host_profile_id                 6210 non-null   float64
#  4   host_name                       6211 non-null   str
#  5   neighbourhood_group             0 non-null      float64
#  6   neighbourhood                   6217 non-null   str
#  7   latitude                        6217 non-null   float64
#  8   longitude                       6217 non-null   float64
#  9   room_type                       6217 non-null   str
#  10  price                           5901 non-null   float64
#  11  minimum_nights                  6216 non-null   float64
# ...

# %% [markdown]
# ## Dallas Findings Summary
#
# **Shape**
# - 6,217 rows and 19 columns
# - Fewer listings than Austin (10,533)
#
# **Key Differences from Austin**
# - Has an extra column: host_profile_id ... will drop when combining cities
# - neighbourhood contains District names, not zip codes like Austin
# - host_id and minimum_nights stored as float64 instead of int64
# - price has 316 null values vs Austin's 16
#
# **Null Values**
# - host_id               ... 6 NULL values
# - host_profile_id       ... 7 NULL values
# - host_name             ... 6 NULL values
# - neighbourhood_group   ... 6217 NULL values
# - price                 ... 316 NULL values
# - last_review           ... 1106 NULL values
# - reviews_per_month     ... 1106 NULL values
# - license               ... 6217 NULL values
#
# **Outliers from df.describe()**
# - Price
#     - min: 5 ... very low even for one night
#     - max: 50000 ... same outlier pattern as Austin
# - minimum_nights
#     - max: 365 ... minimum stay is one year?

# %% [markdown]
# ## Fort Worth EDA

# %%
df = pd.read_csv('../data/listings_FortWorth.csv')
df.head()
# Out:
#         id                                               name  host_id  \
# 0   257869  House w/ Pool in Cultural District/close2downtown  1356081
# 1   299748                                 Rosy's Guest House  1544441
# 2   912371                 Stay in Ft.Worth Cultural District  4895584
# 3  1885626                   Private bedroom in spacious home  7892516
# 4  2130492                Charming "attic room" by TCU campus   826752
#
#   host_name  neighbourhood_group neighbourhood  latitude  longitude  \
# 0    Shayna                  NaN           NaN  32.74186  -97.37857
# 1  Kimberly                  NaN    District 9  32.71696  -97.34170
# 2       V R                  NaN    District 7  32.73643  -97.38305
# 3     Tibor                  NaN           NaN  33.02235  -97.30032
# 4       Lee                  NaN    District 3  32.71192  -97.36889
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.info()
df[['price', 'minimum_nights', 'availability_365', 'number_of_reviews']].describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2081 entries, 0 to 2080
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              2081 non-null   int64
#  1   name                            2081 non-null   str
#  2   host_id                         2081 non-null   int64
#  3   host_name                       2073 non-null   str
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   1012 non-null   str
#  6   latitude                        2081 non-null   float64
#  7   longitude                       2081 non-null   float64
#  8   room_type                       2081 non-null   str
#  9   price                           1856 non-null   float64
#  10  minimum_nights                  2081 non-null   int64
#  11  number_of_reviews               2081 non-null   int64
# ...

# %% [markdown]
# ## Fort Worth Findings Summary
#
# **Shape**
# - 2,081 rows and 18 columns
# - Significantly fewer listings than Austin (10,533) and Dallas (6,217)
#
# **Key Differences from Austin and Dallas**
# - neighbourhood has 1,069 NULL values — over half the listings are missing a neighbourhood
# - No extra columns compared to Austin — same 18 column structure
# - price has 225 null values vs Austin's 16 and Dallas's 316
#
# **Null Values**
# - host_name              ... 8 NULL values
# - neighbourhood_group    ... 2081 NULL values
# - neighbourhood          ... 1069 NULL values
# - price                  ... 225 NULL values
# - last_review            ... 363 NULL values
# - reviews_per_month      ... 363 NULL values
# - license                ... 2081 NULL values
#
# **Outliers from df.describe()**
# - Price
#     - min: 15 ... slightly more reasonable than Austin and Dallas
#     - max: 50,000 ... same outlier pattern across all three cities
#     - mean: $494 ... highest mean of all three cities, heavily skewed by outliers
# - minimum_nights
#     - max: 365 ... same issue as Austin and Dallas
# - neighbourhood
#     - 1,069 missing values ... will need to decide whether to drop rows or fill during cleaning
